# %% [markdown]
# Программно реализовать извлечение стандартных именованных сущностей таких категорий как Person, Location, Organization.
# Корпуса с данными:
#
# - [BSNLP 2017 — Balto-Slavic Natural Language Processing](http://bsnlp-2017.cs.helsinki.fi/shared_task_results.html);
# - [Ukranian NER annotation project](https://github.com/lang-uk/ner-uk).
#
# Корпус выбирайте любой. Метод решения поставленной задачи тоже любой. Результаты будем обсуждать в пятницу. Удачи!

# %%
from nltk import tokenize, word_tokenize, pos_tag, ne_chunk
from nltk.tag import PerceptronTagger, UnigramTagger, BigramTagger
from nltk.data import find
from nltk.corpus import cess_esp as cess

# %% [markdown]
# #### Read filenames for train and test part

# %%
def get_lines(file):
    return [line.replace('\n', '') for line in file.readlines() if line and not line.isspace()]

with open("ner-uk-master/doc/dev-test-split.txt") as file:
    filenames = get_lines(file)
    train_filenames = filenames[1:156]
    test_filenames = filenames[159:231]

# %% [markdown]
# #### Read train and test documents
# Fixed filenames in dev-test-split.txt

# %%
def get_tags_and_words(line):
    return (line.split("\t")[2], line.split("\t")[1].split(' ')[0])

def read_file(filename):
    with open(filename, encoding='utf-8') as file:
        return [get_tags_and_words(line) for line in get_lines(file)]

def read_data(filenames):
    return [read_file("ner-uk-master/data/" + filename + '.ann') for filename in filenames]

def remove_falsy(lst):
    return [x for x in lst if x]
    
training_corpus = remove_falsy(read_data(train_filenames))
test_corpus = remove_falsy(read_data(test_filenames))

# %% [markdown]
# Use the pretrain model (the default constructor)? Or just train?

# %%
with open("ner-uk-master/doc/sent-tokenization.txt", encoding="utf-8") as file:
    sentences = get_lines(file)

# %%
unitagger = UnigramTagger(training_corpus)

# %%
unitagger.evaluate(test_corpus)
# Out:
# 0.21092029942756496

# %%
bitagger = BigramTagger(training_corpus, backoff=unitagger)

# %%
bitagger.evaluate(test_corpus)
# Out:
# 0.21092029942756496

# %%
tagger = PerceptronTagger(load=False)
tagger.train(training_corpus)

# %%
tagger.evaluate(test_corpus)
# Out:
# 0.693967415235579

# %%
for sent in sentences:
    if sent and not sent.isspace():
        words = nltk.tokenize.word_tokenize(sent)
        pos_tags_words = pos_tag(words)
        print(pos_tags_words)
# Out:
# [('Це', 'ПЕРС'), ('просте', 'ЛОК'), ('речення', 'ОРГ'), ('.', '.')]
# [('Панк-рок', 'ЛОК'), ('—', 'ОРГ'), ('напрям', 'ЛОК'), ('у', 'ОРГ'), ('рок-музиці', 'ЛОК'), (',', ','), ('що', 'ПЕРС'), ('виник', 'ЛОК'), ('у', 'ЛОК'), ('середині', 'ЛОК'), ('1970-х', 'ОРГ'), ('рр', 'ПЕРС'), ('.', '.'), ('у', 'ЛОК'), ('США', 'ЛОК'), ('і', 'ЛОК'), ('Великобританії', 'ПЕРС'), ('.', '.')]
# [('Разом', 'ЛОК'), ('із', 'ОРГ'), ('втечами', 'ЛОК'), (',', ','), ('вже', 'ЛОК'), ('у', 'ОРГ'), ('XV', 'ЛОК'), ('ст', 'ОРГ'), ('.', '.'), ('почастішали', 'ОРГ'), ('збройні', 'ЛОК'), ('виступи', 'ОРГ'), ('селян', 'ЛОК'), ('.', '.')]
# [('На', 'ПЕРС'), ('початок', 'ЛОК'), ('1994', 'CD'), ('р.', 'ЛОК'), ('державний', 'ПЕРС'), ('борг', 'ЛОК'), ('України', 'ЛОК'), ('становив', 'ЛОК'), ('4,8', 'CD'), ('млрд', 'ЛОК'), ('.', '.'), ('дол', 'ЛОК'), ('.', '.')]
# [('Київ', 'ЛОК'), (',', ','), ('вул', 'ЛОК'), ('.', '.'), ('Сагайдачного', 'ПЕРС'), (',', ','), ('буд', 'ЛОК'), ('.', '.'), ('43', 'CD'), (',', ','), ('кв', 'ПЕРС'), ('.', '.'), ('4', 'CD'), ('.', '.')]
# [('Наша', 'ПЕРС'), ('зустріч', 'ЛОК'), ('з', 'ЛОК'), ('А.', 'ПЕРС'), ('Марчуком', 'ПЕРС'), ('і', 'ЛОК'), ('Г.', 'ПЕРС'), ('В.', 'ПЕРС'), ('Тріскою', 'ПЕРС'), ('відбулася', 'ЛОК'), ('в', 'ЛОК'), ('грудні', 'ПЕРС'), ('минулого', 'ПЕРС'), ('року', 'ЛОК'), ('.', '.')]
# [('Наша', 'ПЕРС'), ('зустріч', 'ЛОК'), ('з', 'ЛОК'), ('А.Марчуком', 'ПЕРС'), ('і', 'ЛОК'), ('М.В.Хвилею', 'ПЕРС'), ('відбулася', 'ЛОК'), ('в', 'ЛОК'), ('грудні', 'ПЕРС'), ('минулого', 'ПЕРС'), ('року', 'ЛОК'), ('.', '.')]
# [('Комендант', 'ЛОК'), ('преподобний', 'ЛОК'), ('С.\\u00A0Мокітімі', 'ЛОК')]
# [('Комендант', 'ЛОК'), ('преподобний', 'ЛОК'), ('С.\\u00A0С.\\u00A0Мокітімі', 'ЛОК'), ('1', 'CD'), ('.', '.')]
# [('Комендант', 'ЛОК'), ('преподобний', 'ЛОК'), ('С.\\u00A0С', 'ЛОК'), ('.', '.'), ('Мокітімі', 'ПЕРС'), ('2', 'CD'), ('.', '.')]
# [('Склад', 'ЛОК'), (':', ':'), ('акад', 'NN'), ('.', '.'), ('Вернадський', 'ПЕРС'), (',', ','), ('проф', 'ЛОК'), ('.', '.'), ('Харченко', 'ПЕРС'), (',', ','), ('доц', 'ЛОК'), ('.', '.'), ('Семеняк', 'ЛОК'), ('.', '.')]
# [('Опергрупа', 'ПЕРС'), ('приїхала', 'ЛОК'), ('в', 'ЛОК'), ('с.', 'ПЕРС'), ('Лісове', 'ЛОК'), ('.', '.')]
# [('300', 'CD'), ('р.', 'ОРГ'), ('до', 'ПЕРС'), ('н.', 'ОРГ'), ('е', 'ЛОК'), ('.', '.')]
# [('З', 'ЛОК'), ('300', 'CD'), ('р.', 'ЛОК'), ('до', 'ПЕРС'), ('н.е.', 'ЛОК'), (',', ','), ('і', 'ПЕРС'), ('по', 'ЛОК'), ('цей', 'ЛОК'), ('день', 'ЛОК'), ('.', '.')]
# [('Пролісок', 'ПЕРС'), ('(', '('), ('рос', 'UH'), ('.', '.'), ('пролесок', 'ЛОК'), (')', ')'), ('—', 'ПЕРС'), ('маленька', 'ЛОК'), ('квітка', 'ЛОК'), ('.', '.')]
# [('Квітка', 'ЛОК'), ('Цісик', 'ОРГ'), ('(', '('), ('англ', 'ОРГ'), ('.', '.'), ('Kvitka', 'ОРГ'), ('Cisyk', 'ЛОК'), ('також', 'ОРГ'), ('Kacey', 'ПЕРС'), ('Cisyk', 'ОРГ'), ('від', 'ЛОК'), ('ініціалів', 'ПЕРС'), ('К.С', 'ЛОК'), ('.', '.'), (')', ')'), (';', ':'), ('4', 'CD'), ('квітня', '$'), ('1953р.', 'CD'), (',', ','), ('Квінз', 'ЛОК'), (',', ','), ('Нью-Йорк', 'JJ'), ('—', 'ПЕРС'), ('29', 'CD'), ('березня', 'NN'), ('1998', 'CD'), ('р.', 'NN'), (',', ','), ('Мангеттен', 'ОРГ'), (',', ','), ('Нью-Йорк', 'ОРГ'), (')', ')'), ('—', 'ОРГ'), ('американська', 'ЛОК'), ('співачка', 'ПЕРС'), ('українського', 'ПЕРС'), ('походження', 'ЛОК'), ('.', '.')]
# [('До', 'ПЕРС'), ('Інституту', 'ЛОК'), ('ім', 'ЛОК'), ('.', '.'), ('Глієра', 'ПЕРС'), ("під'їжджає", 'ЛОК'), ('чорне', 'ЛОК'), ('авто', 'ЛОК'), ('.', '.')]
# [('До', 'ПЕРС'), ('Інституту', 'ЛОК'), ('ім', 'ЛОК'), ('.', '.'), ('акад', 'ЛОК'), ('.', '.'), ('Вернадського', 'ПЕРС'), ('.', '.')]
# [('До', 'ПЕРС'), ('вулиці', 'ЛОК'), ('гетьмана', 'ПЕРС'), ('Скоропадського', 'ПЕРС'), ("під'їжджає", 'ЛОК'), ('чорне', 'ЛОК'), ('авто', 'ЛОК'), ('.', '.')]
# [('До', 'ПЕРС'), ('табору', 'ЛОК'), ('«', 'ЛОК'), ('Артек', 'ПЕРС'), ('»', 'ЛОК'), ('.', '.')]
# [('Спільні', 'ЛОК'), ('пральні', 'ЛОК'), ('й', 'ЛОК'), ('т.', 'ЛОК'), ('д', 'ЛОК'), ('.', '.')]
# [('Спільні', 'ЛОК'), ('пральні', 'ЛОК'), ('й', 'ЛОК'), ('т.', 'ЛОК'), ('д.', 'ЛОК'), ('й', 'ЛОК'), ('т.', 'ЛОК'), ('п', 'ЛОК'), ('.', '.')]
# [('див', 'ПЕРС'), ('.', '.'), ('стор', 'VB'), ('.', '.'), ('24', 'CD'), ('.', '.')]
# [('Є.Бакуліна', 'ЛОК')]
# [('Від', 'ПЕРС'), ('англ.\\n', 'ОРГ'), ('File', 'ЛОК'), ('.', '.')]
# [('Від', 'ПЕРС'), ('фр', 'ЛОК'), ('.', '.'), ('\\nparachute', 'ЛОК'), ('.', '.')]
# [('В', 'ПЕРС'), ('цих', 'ЛОК'), ('світлих', 'ЛОК'), ('просторих', 'ЛОК'), ('апартаментах', 'ЛОК'), ('...', ':'), ('м', 'ЛОК'), ('’', 'ПЕРС'), ('які', 'ПЕРС'), ('крісла', 'РІЗН'), (',', ','), ('килими', 'UH'), (',', ','), ('дорогі', 'ЛОК'), ('статуетки', 'ЛОК')]
# [('(', '('), ('вони', 'ЛОК'), ('самі', 'ПЕРС'), ('це', 'ЛОК'), ('визнали', 'ЛОК'), ('.', '.'), ('-', ':'), ('Ред', 'NN'), ('.', '.'), (')', ')')]
# [('Всього', 'ПЕРС'), ('33', 'CD'), ('тис', 'NN'), ('.', '.'), ('356', 'CD'), ('особи', 'ЛОК')]
# [('Всього', 'ПЕРС'), ('33', 'CD'), ('тис', 'NN'), ('.', '.'), ('(', '('), ('за', 'ПЕРС'), ('словами', 'ОРГ'), ('прораба', 'ЛОК'), (')', ')')]
# [('з', 'ПЕРС'), ('яких', 'ЛОК'), ('приблизно', 'ЛОК'), ('1,2', 'CD'), ('тис', 'ЛОК'), ('.', '.'), ('–', 'ПЕРС'), ('чоловіки', 'ЛОК'), ('.', '.')]
# [('У', 'ЛОК'), ('с.', 'ОРГ'), ('Вижва', 'ЛОК')]
# [('Книжка', 'ЛОК'), ('(', '('), ('с', 'UH'), ('.', '.'), ('200', 'CD'), (')', ')')]
# [('позначені', 'ЛОК'), (':', ':'), ('«', 'ПЕРС'), ('с', 'ПЕРС'), ('.', '.'), ('Вижва', 'ПЕРС'), ('»', 'ЛОК')]
# [('Микола', 'ПЕРС'), ('Васюк', 'ЛОК'), ('(', '('), ('с.', 'ПЕРС'), ('Корнієнки', 'ЛОК'), (',', ','), ('Полтавська', 'ПЕРС'), ('обл', 'ОРГ'), ('.', '.'), (')', ')')]
# [('U.S.', 'NNP'), ('Marine', 'ЛОК')]
# [('B.B', 'ПЕРС'), ('.', '.'), ('King', 'VBG')]
# [('Церква', 'ПЕРС'), ('Св', 'ЛОК'), ('.', '.'), ('Духа', 'ПЕРС'), ('і', 'ЛОК'), ('церква', 'ЛОК'), ('св', 'ЛОК'), ('.', '.'), ('Духа', 'ЛОК')]
# [('Валерій', 'ПЕРС'), ('(', '('), ('міліціонер-пародист', 'ОРГ'), ('.', '.'), ('–', 'ОРГ'), ('Авт', 'ПЕРС'), ('.', '.'), (')', ')'), ('стане', 'VBD'), ('пародистом', 'ЛОК'), ('.', '.')]
# [('Сьогодні', 'ЛОК'), ('(', '('), ('у', 'ЛОК'), ('четвер', 'RB'), ('.', '.'), ('-', ':'), ('Ред', 'NN'), ('.', '.'), (')', ')'), (',', ','), ('вранці', 'UH'), ('.', '.')]
# [('(', '('), ('[', 'ОРГ'), ('27', 'CD'), (']', 'ОРГ'), ('див', 'ПЕРС'), ('.', '.'), ('Тиждень', 'ПЕРС'), ('№', '$'), ('9', 'CD'), (',', ','), ('2008', 'CD'), (')', ')')]
# [('Всього', 'ПЕРС'), ('33', 'CD'), ('тис', 'NNS'), ('.', '.')]
# [('А', 'ПЕРС'), ('можей', 'ОРГ'), ('й', 'ЛОК'), ('більше', 'ЛОК')]
# [('Їх', 'ПЕРС'), ('було', 'ЛОК'), ('7,5', 'CD'), ('млн', 'NNS'), ('.', '.')]
# [('В', 'ПЕРС'), ('кожного', 'ЛОК'), ('була', 'ПЕРС'), ('сорочка', 'ЛОК'), ('.', '.')]
# [('Довжиною', 'ПЕРС'), ('30', 'CD'), ('с', 'NNS'), ('.', '.')]
# [('Поїхали', 'ЛОК'), ('.', '.')]
# [('Швидкістю', 'ПЕРС'), ('30', 'CD'), ('м/с', 'NNS'), ('.', '.')]
# [('Поїхали', 'ЛОК'), ('.', '.')]
# [('Останні', 'ПЕРС'), ('100', 'CD'), ('м', 'NNS'), ('.', '.')]
# [('І', 'ПЕРС'), ('тут', 'ЛОК'), ('все', 'ЛОК'), ('пропало', 'ЛОК'), ('.', '.')]
# [('Корисна', 'ЛОК'), ('площа', 'ЛОК'), ('67', 'CD'), ('тис', 'ЛОК'), ('.', '.'), ('кв', 'ПЕРС'), ('.', '.'), ('м', 'ЛОК'), ('.', '.')]
# [('У', 'ЛОК'), ('1954', 'CD'), ('році', 'ЛОК'), ('над', 'ПЕРС'), ('Держпромом', 'ПЕРС'), ('...', ':')]
# [('На', 'ПЕРС'), ('0,6°C', 'CD'), ('.', '.')]
# [('Але', 'ПЕРС'), ('ми', 'ОРГ'), ('все', 'ЛОК'), ('маємо', 'ОРГ'), ('.', '.')]
# [('На', 'ПЕРС'), ('0,6°С', 'CD'), ('.', '.')]
# [('Але', 'ПЕРС'), ('ми', 'ОРГ'), ('все', 'ЛОК'), ('маємо', 'ОРГ'), ('.', '.')]
# [('На', 'ПЕРС'), ('0,6', 'CD'), ('°C', 'NNS'), ('.', '.')]
# [('Але', 'ПЕРС'), ('ми', 'ОРГ'), ('все', 'ЛОК'), ('маємо', 'ОРГ'), ('.', '.')]
# [('На', 'ПЕРС'), ('0,6', 'CD'), ('°С', 'NNS'), ('.', '.')]
# [('Але', 'ПЕРС'), ('ми', 'ОРГ'), ('все', 'ЛОК'), ('маємо', 'ОРГ'), ('.', '.')]
# [('Приїхав', 'ПЕРС'), ('у', 'ЛОК'), ('США', 'ЛОК'), ('.', '.')]
# [('Проте', 'ПЕРС'), ('на', 'ЛОК'), ('другий', 'ЛОК'), ('рік', 'ЛОК'), ('.', '.')]
# [('Маємо', 'ПЕРС'), ('страшне', 'ЛОК'), ('диво', 'ЛОК'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('.', '.')]
# [('І', 'ПЕРС'), ('кращого', 'ЛОК'), ('варіанту', 'ЛОК'), ('немає', 'ЛОК'), ('.', '.')]
# [('Вони', 'ПЕРС'), ('приїхали', 'ЛОК'), ('в', 'ЛОК'), ('Париж', 'ЛОК'), ('.', '.')]
# [('Але', 'ПЕРС'), ('там', 'ЛОК'), ('їм', 'ЛОК'), ('геть', 'ЛОК'), ('не', 'ЛОК'), ('сподобалося', 'ЛОК'), ('.', '.')]

# %%
with open("ner-uk-master/doc/word-tokenization.txt", encoding="utf-8") as file:
    small_sentences = get_lines(file)

# %%
for sent in small_sentences:
    if sent and not sent.isspace():
        words = nltk.tokenize.word_tokenize(sent)
        pos_tags_words = pos_tag(words)
        print(pos_tags_words)
# Out:
# [('http', 'NNS'), (':', ':'), ('//youtube.com:80/herewego', 'VB'), ('?', '.'), ('start=11', 'VB'), ('&', 'CC'), ('quality=high', 'VB'), ('%', 'NN'), ('3F', 'CD')]
# [('http', 'NNS'), (':', ':'), ('//youtube.com:80/herewego', 'VB'), ('?', '.'), ('start=11', 'VB'), ('&', 'CC'), ('quality=high', 'VB'), ('%', 'NN'), ('3F', 'CD')]
# [('300', 'CD'), ('грн', 'ЛОК'), ('на', 'ПЕРС'), ('балансі', 'ЛОК')]
# [('300', 'CD'), ('грн', 'ЛОК'), ('на', 'ПЕРС'), ('балансі', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('2,2', 'CD'), ('мільйона', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('2,2', 'CD'), ('мільйона', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('84,46', 'CD'), ('мільйона', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('84,46', 'CD'), ('мільйона', 'ЛОК')]
# [('в', 'ЛОК'), ('1996,1997,1998', 'CD')]
# [('в', 'ЛОК'), ('1996', 'CD'), (',', ','), ('1997', 'CD'), (',', ','), ('1998', 'CD')]
# [('надійшло', 'ПЕРС'), ('2', 'CD'), ('000', 'CD'), ('тон', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('2', 'CD'), ('000', 'CD'), ('тон', 'ЛОК')]
# [('сталося', 'ПЕРС'), ('14.07.2001', 'CD'), ('вночі', 'ЛОК')]
# [('сталося', 'ПЕРС'), ('14.07.2001', 'CD'), ('вночі', 'ЛОК')]
# [('вчора', 'ЛОК'), ('о', 'ОРГ'), ('7.30', 'CD'), ('ранку', 'ЛОК')]
# [('вчора', 'ЛОК'), ('о', 'ОРГ'), ('7.30', 'CD'), ('ранку', 'ЛОК')]
# [('Вони', 'ПЕРС'), ('прийшли', 'ЛОК'), ('додому', 'ЛОК'), ('.', '.')]
# [('Вони', 'ПЕРС'), ('прийшли', 'ЛОК'), ('додому', 'ЛОК'), ('.', '.')]
# [('Вони', 'ПЕРС'), ('прийшли', 'ЛОК'), ('пʼятими', 'ЛОК'), ('зів', 'ЛОК'), ('’', 'ЛОК'), ('ялими', 'ЛОК'), ('.', '.')]
# [('Вони', 'ПЕРС'), ('прийшли', 'ЛОК'), ('пʼятими', 'ЛОК'), ('зів', 'ЛОК'), ('’', 'ЛОК'), ('ялими', 'ЛОК'), ('.', '.')]
# [('я', 'ПЕРС'), ('українець', 'ЛОК'), ('(', '('), ('сміється', 'ЛОК')]
# [('я', 'ПЕРС'), ('українець', 'ЛОК'), ('(', '('), ('сміється', 'ЛОК')]
# [('ОУН', 'ПЕРС'), ('(', '('), ('б', 'ЛОК'), (')', ')'), ('та', 'ПЕРС'), ('КП', 'ЛОК'), ('(', '('), ('б', 'ЛОК'), (')', ')'), ('У', 'ЛОК')]
# [('ОУН', 'ПЕРС'), ('(', '('), ('б', 'ЛОК'), (')', ')'), ('та', 'ПЕРС'), ('КП', 'ЛОК'), ('(', '('), ('б', 'ЛОК'), (')', ')'), ('У', 'ЛОК')]
# [('Негода', 'ПЕРС'), ('є', 'ЛОК'), ('...', ':'), ('заступником', 'ЛОК')]
# [('Негода', 'ПЕРС'), ('є', 'ЛОК'), ('...', ':'), ('заступником', 'ЛОК')]
# [('Запагубили', 'ЛОК'), ('!', '.'), ('..', 'ЛОК'), ('також', 'ЛОК')]
# [('Запагубили', 'ЛОК'), ('!', '.'), ('..', 'ЛОК'), ('також', 'ЛОК')]
# [('Цей', 'ПЕРС'), ('графин', 'ЛОК'), ('.', '.')]
# [('Цей', 'ПЕРС'), ('графин', 'ЛОК'), ('.', '.')]
# [('—', 'ПЕРС'), ('Гм', 'ОРГ'), ('.', '.')]
# [('—', 'ПЕРС'), ('Гм', 'ОРГ'), ('.', '.')]
# [('Засідав', 'ЛОК'), ('І.Єрмолюк', 'ОРГ'), ('.', '.')]
# [('Засідав', 'ЛОК'), ('І', 'ОРГ'), ('.', '.'), ('Єрмолюк', 'ОРГ'), ('.', '.')]
# [('Засідав', 'ЛОК'), ('І.П.Єрмолюк', 'ОРГ'), ('.', '.')]
# [('Засідав', 'ЛОК'), ('І', 'ОРГ'), ('.', '.'), ('П', 'ОРГ'), ('.', '.'), ('Єрмолюк', 'ОРГ'), ('.', '.')]
# [('140', 'CD'), ('тис', 'ЛОК'), ('.', '.'), ('працівників', 'ЛОК')]
# [('140', 'CD'), ('тис', 'ЛОК'), ('.', '.'), ('працівників', 'ЛОК')]
# [('проф', 'ЛОК'), ('.', '.'), ('Артюхов', 'ЛОК')]
# [('проф', 'ЛОК'), ('.', '.'), ('Артюхов', 'ЛОК')]
# [('до', 'ПЕРС'), ('н.', 'ЛОК'), ('е', 'ЛОК'), ('.', '.')]
# [('до', 'ПЕРС'), ('н.', 'ЛОК'), ('е', 'ЛОК'), ('.', '.')]
# [('до', 'ПЕРС'), ('н.е', 'ЛОК'), ('.', '.')]
# [('до', 'ПЕРС'), ('н.', 'ЛОК'), ('е', 'ЛОК'), ('.', '.')]
# [('1998', 'CD'), ('р.н', 'ЛОК'), ('.', '.')]
# [('1998', 'CD'), ('р.', 'ОРГ'), ('н', 'ЛОК'), ('.', '.')]
# [('18-19', 'CD'), ('ст.ст', 'ОРГ'), ('.', '.'), ('були', 'ЛОК')]
# [('18-19', 'CD'), ('ст', 'ОРГ'), ('.', '.'), ('ст', 'ОРГ'), ('.', '.'), ('були', 'ЛОК')]
# [('І', 'ПЕРС'), ('ст', 'ЛОК'), ('.', '.'), ('11', 'CD')]
# [('І', 'ПЕРС'), ('ст', 'ЛОК'), ('.', '.'), ('11', 'CD')]
# [('У', 'ЛОК'), ('с.', 'ОРГ'), ('Вижва', 'ЛОК')]
# [('У', 'ЛОК'), ('с.', 'ОРГ'), ('Вижва', 'ЛОК')]
# [('Довжиною', 'ПЕРС'), ('30', 'CD'), ('с.', 'ЛОК'), ('з', 'ПЕРС'), ('гаком', 'ЛОК'), ('.', '.')]
# [('Довжиною', 'ПЕРС'), ('30', 'CD'), ('с', 'NN'), ('.', '.'), ('з', 'CC'), ('гаком', 'ПЕРС'), ('.', '.')]
# [('100', 'CD'), ('м.', 'ОРГ'), ('дороги', 'NNS'), ('.', '.')]
# [('100', 'CD'), ('м', 'ОРГ'), ('.', '.'), ('дороги', 'ОРГ'), ('.', '.')]
# [('На', 'ПЕРС'), ('висоті', 'ЛОК'), ('4000', 'CD'), ('м', 'ЛОК'), ('...', ':')]
# [('На', 'ПЕРС'), ('висоті', 'ЛОК'), ('4000', 'CD'), ('м', 'ЛОК'), ('...', ':')]
# [('№47', 'ПЕРС'), ('(', '('), ('м.', 'ЛОК'), ("Слов'янськ", 'ЛОК'), (')', ')')]
# [('№47', 'ПЕРС'), ('(', '('), ('м.', 'ЛОК'), ("Слов'янськ", 'ЛОК'), (')', ')')]
# [('с.-г', 'ЛОК'), ('.', '.')]
# [('с.-г', 'ЛОК'), ('.', '.')]
# [('100', 'CD'), ('грн', 'ЛОК'), ('.', '.'), ('в', 'ЛОК'), ('банк', 'ЛОК')]
# [('100', 'CD'), ('грн', 'ЛОК'), ('.', '.'), ('в', 'ЛОК'), ('банк', 'ЛОК')]
# [('таке', 'ПЕРС'), ('та', 'ЛОК'), ('ін', 'ЛОК'), ('.', '.')]
# [('таке', 'ПЕРС'), ('та', 'ЛОК'), ('ін', 'ЛОК'), ('.', '.')]
# [('і', 'ПЕРС'), ('т.', 'ЛОК'), ('ін', 'ЛОК'), ('.', '.')]
# [('і', 'ПЕРС'), ('т.', 'ЛОК'), ('ін', 'ЛОК'), ('.', '.')]
# [('Інститут', 'ПЕРС'), ('ім', 'ЛОК'), ('.', '.'), ('акад', 'ЛОК'), ('.', '.'), ('Вернадського', 'ПЕРС'), ('.', '.')]
# [('Інститут', 'ПЕРС'), ('ім', 'ЛОК'), ('.', '.'), ('акад', 'ЛОК'), ('.', '.'), ('Вернадського', 'ПЕРС'), ('.', '.')]
# [('Палац', 'ПЕРС'), ('ім', 'ЛОК'), ('.', '.'), ('гетьмана', 'ПЕРС'), ('Скоропадського', 'ЛОК'), ('.', '.')]
# [('Палац', 'ПЕРС'), ('ім', 'ЛОК'), ('.', '.'), ('гетьмана', 'ПЕРС'), ('Скоропадського', 'ЛОК'), ('.', '.')]
# [('від', 'ЛОК'), ('лат', 'ОРГ'), ('.', '.'), ('momento', 'VB')]
# [('від', 'ЛОК'), ('лат', 'ОРГ'), ('.', '.'), ('momento', 'VB')]
# [('на', 'ЛОК'), ('1-кімн', 'ОРГ'), ('.', '.'), ('кв', 'ОРГ'), ('.', '.'), ('в', 'ЛОК'), ('центрі', 'ЛОК')]
# [('на', 'ЛОК'), ('1-кімн', 'ОРГ'), ('.', '.'), ('кв', 'ОРГ'), ('.', '.'), ('в', 'ЛОК'), ('центрі', 'ЛОК')]
# [('Валерій', 'ПЕРС'), ('(', '('), ('міліціонер-пародист.–', 'ОРГ'), ('Авт', 'ПЕРС'), ('.', '.'), (')', ')'), ('стане', 'VBD'), ('пародистом', 'ЛОК'), ('.', '.')]
# [('Валерій', 'ПЕРС'), ('(', '('), ('міліціонер-пародист', 'ОРГ'), ('.', '.'), ('–', 'ОРГ'), ('Авт', 'ПЕРС'), ('.', '.'), (')', ')'), ('стане', 'VBD'), ('пародистом', 'ЛОК'), ('.', '.')]
# [('Сьогодні', 'ЛОК'), ('(', '('), ('у', 'ЛОК'), ('четвер', 'RB'), ('.', '.'), ('—', 'VB'), ('Ред', 'ЛОК'), ('.', '.'), (')', ')'), (',', ','), ('вранці', 'UH'), ('.', '.')]
# [('Сьогодні', 'ЛОК'), ('(', '('), ('у', 'ЛОК'), ('четвер', 'RB'), ('.', '.'), ('—', 'VB'), ('Ред', 'ЛОК'), ('.', '.'), (')', ')'), (',', ','), ('вранці', 'UH'), ('.', '.')]
# [('Fair', 'ПЕРС'), ('trade', 'NN'), ('[', 'ПЕРС'), ('«', 'ПЕРС'), ('Справедлива', 'ЛОК'), ('торгівля', 'ЛОК'), ('»', 'ЛОК'), ('.', '.'), ('–', 'ПЕРС'), ('Авт', 'ПЕРС'), ('.', '.'), (']', 'VB'), (',', ','), ('який', 'VB'), ('стежить', 'ПЕРС'), ('за', 'ОРГ'), ('тим', 'ЛОК'), (',', ','), ('щоб', 'ПЕРС'), ('у', 'ЛОК'), ('країнах', 'ЛОК')]
# [('Fair', 'ПЕРС'), ('trade', 'NN'), ('[', 'ПЕРС'), ('«', 'ПЕРС'), ('Справедлива', 'ЛОК'), ('торгівля', 'ЛОК'), ('»', 'ЛОК'), ('.', '.'), ('–', 'ПЕРС'), ('Авт', 'ПЕРС'), ('.', '.'), (']', 'VB'), (',', ','), ('який', 'VB'), ('стежить', 'ПЕРС'), ('за', 'ОРГ'), ('тим', 'ЛОК'), (',', ','), ('щоб', 'ПЕРС'), ('у', 'ЛОК'), ('країнах', 'ЛОК')]
# [('диво', 'ПЕРС'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('.', '.')]
# [('диво', 'ПЕРС'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('.', '.')]
# [('диво', 'ПЕРС'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('...', ':')]
# [('диво', 'ПЕРС'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('...', ':')]

# %%
import os

filenames = [filename[:-4] for filename in os.listdir('ner-uk-master/data/') \
             if filename.endswith(".ann") and not filename.endswith(".tok.ann")]

tagged_sentences = remove_falsy(read_data(filenames))

idx = int(len(tagged_sentences)*0.2)
print(len(tagged_sentences))
print(idx)

train_sentences = tagged_sentences[idx:]
test_sentences = tagged_sentences[:idx]

tagger = PerceptronTagger(load=False)
tagger.train(train_sentences)
# Out:
# 216
# 43

# %%
tagger.evaluate(test_sentences)
# Out:
# 0.506339144215531

# %%
for sent in sentences:
    if sent and not sent.isspace():
        words = nltk.tokenize.word_tokenize(sent)
        pos_tags_words = pos_tag(words)
        print(pos_tags_words)
# Out:
# [('Це', 'ПЕРС'), ('просте', 'ЛОК'), ('речення', 'ОРГ'), ('.', '.')]
# [('Панк-рок', 'ЛОК'), ('—', 'ОРГ'), ('напрям', 'ЛОК'), ('у', 'ОРГ'), ('рок-музиці', 'ЛОК'), (',', ','), ('що', 'ПЕРС'), ('виник', 'ЛОК'), ('у', 'ЛОК'), ('середині', 'ЛОК'), ('1970-х', 'ОРГ'), ('рр', 'ПЕРС'), ('.', '.'), ('у', 'ЛОК'), ('США', 'ЛОК'), ('і', 'ЛОК'), ('Великобританії', 'ПЕРС'), ('.', '.')]
# [('Разом', 'ЛОК'), ('із', 'ОРГ'), ('втечами', 'ЛОК'), (',', ','), ('вже', 'ЛОК'), ('у', 'ОРГ'), ('XV', 'ЛОК'), ('ст', 'ОРГ'), ('.', '.'), ('почастішали', 'ОРГ'), ('збройні', 'ЛОК'), ('виступи', 'ОРГ'), ('селян', 'ЛОК'), ('.', '.')]
# [('На', 'ПЕРС'), ('початок', 'ЛОК'), ('1994', 'CD'), ('р.', 'ЛОК'), ('державний', 'ПЕРС'), ('борг', 'ЛОК'), ('України', 'ЛОК'), ('становив', 'ЛОК'), ('4,8', 'CD'), ('млрд', 'ЛОК'), ('.', '.'), ('дол', 'ЛОК'), ('.', '.')]
# [('Київ', 'ЛОК'), (',', ','), ('вул', 'ЛОК'), ('.', '.'), ('Сагайдачного', 'ПЕРС'), (',', ','), ('буд', 'ЛОК'), ('.', '.'), ('43', 'CD'), (',', ','), ('кв', 'ПЕРС'), ('.', '.'), ('4', 'CD'), ('.', '.')]
# [('Наша', 'ПЕРС'), ('зустріч', 'ЛОК'), ('з', 'ЛОК'), ('А.', 'ПЕРС'), ('Марчуком', 'ПЕРС'), ('і', 'ЛОК'), ('Г.', 'ПЕРС'), ('В.', 'ПЕРС'), ('Тріскою', 'ПЕРС'), ('відбулася', 'ЛОК'), ('в', 'ЛОК'), ('грудні', 'ПЕРС'), ('минулого', 'ПЕРС'), ('року', 'ЛОК'), ('.', '.')]
# [('Наша', 'ПЕРС'), ('зустріч', 'ЛОК'), ('з', 'ЛОК'), ('А.Марчуком', 'ПЕРС'), ('і', 'ЛОК'), ('М.В.Хвилею', 'ПЕРС'), ('відбулася', 'ЛОК'), ('в', 'ЛОК'), ('грудні', 'ПЕРС'), ('минулого', 'ПЕРС'), ('року', 'ЛОК'), ('.', '.')]
# [('Комендант', 'ЛОК'), ('преподобний', 'ЛОК'), ('С.\\u00A0Мокітімі', 'ЛОК')]
# [('Комендант', 'ЛОК'), ('преподобний', 'ЛОК'), ('С.\\u00A0С.\\u00A0Мокітімі', 'ЛОК'), ('1', 'CD'), ('.', '.')]
# [('Комендант', 'ЛОК'), ('преподобний', 'ЛОК'), ('С.\\u00A0С', 'ЛОК'), ('.', '.'), ('Мокітімі', 'ПЕРС'), ('2', 'CD'), ('.', '.')]
# [('Склад', 'ЛОК'), (':', ':'), ('акад', 'NN'), ('.', '.'), ('Вернадський', 'ПЕРС'), (',', ','), ('проф', 'ЛОК'), ('.', '.'), ('Харченко', 'ПЕРС'), (',', ','), ('доц', 'ЛОК'), ('.', '.'), ('Семеняк', 'ЛОК'), ('.', '.')]
# [('Опергрупа', 'ПЕРС'), ('приїхала', 'ЛОК'), ('в', 'ЛОК'), ('с.', 'ПЕРС'), ('Лісове', 'ЛОК'), ('.', '.')]
# [('300', 'CD'), ('р.', 'ОРГ'), ('до', 'ПЕРС'), ('н.', 'ОРГ'), ('е', 'ЛОК'), ('.', '.')]
# [('З', 'ЛОК'), ('300', 'CD'), ('р.', 'ЛОК'), ('до', 'ПЕРС'), ('н.е.', 'ЛОК'), (',', ','), ('і', 'ПЕРС'), ('по', 'ЛОК'), ('цей', 'ЛОК'), ('день', 'ЛОК'), ('.', '.')]
# [('Пролісок', 'ПЕРС'), ('(', '('), ('рос', 'UH'), ('.', '.'), ('пролесок', 'ЛОК'), (')', ')'), ('—', 'ПЕРС'), ('маленька', 'ЛОК'), ('квітка', 'ЛОК'), ('.', '.')]
# [('Квітка', 'ЛОК'), ('Цісик', 'ОРГ'), ('(', '('), ('англ', 'ОРГ'), ('.', '.'), ('Kvitka', 'ОРГ'), ('Cisyk', 'ЛОК'), ('також', 'ОРГ'), ('Kacey', 'ПЕРС'), ('Cisyk', 'ОРГ'), ('від', 'ЛОК'), ('ініціалів', 'ПЕРС'), ('К.С', 'ЛОК'), ('.', '.'), (')', ')'), (';', ':'), ('4', 'CD'), ('квітня', '$'), ('1953р.', 'CD'), (',', ','), ('Квінз', 'ЛОК'), (',', ','), ('Нью-Йорк', 'JJ'), ('—', 'ПЕРС'), ('29', 'CD'), ('березня', 'NN'), ('1998', 'CD'), ('р.', 'NN'), (',', ','), ('Мангеттен', 'ОРГ'), (',', ','), ('Нью-Йорк', 'ОРГ'), (')', ')'), ('—', 'ОРГ'), ('американська', 'ЛОК'), ('співачка', 'ПЕРС'), ('українського', 'ПЕРС'), ('походження', 'ЛОК'), ('.', '.')]
# [('До', 'ПЕРС'), ('Інституту', 'ЛОК'), ('ім', 'ЛОК'), ('.', '.'), ('Глієра', 'ПЕРС'), ("під'їжджає", 'ЛОК'), ('чорне', 'ЛОК'), ('авто', 'ЛОК'), ('.', '.')]
# [('До', 'ПЕРС'), ('Інституту', 'ЛОК'), ('ім', 'ЛОК'), ('.', '.'), ('акад', 'ЛОК'), ('.', '.'), ('Вернадського', 'ПЕРС'), ('.', '.')]
# [('До', 'ПЕРС'), ('вулиці', 'ЛОК'), ('гетьмана', 'ПЕРС'), ('Скоропадського', 'ПЕРС'), ("під'їжджає", 'ЛОК'), ('чорне', 'ЛОК'), ('авто', 'ЛОК'), ('.', '.')]
# [('До', 'ПЕРС'), ('табору', 'ЛОК'), ('«', 'ЛОК'), ('Артек', 'ПЕРС'), ('»', 'ЛОК'), ('.', '.')]
# [('Спільні', 'ЛОК'), ('пральні', 'ЛОК'), ('й', 'ЛОК'), ('т.', 'ЛОК'), ('д', 'ЛОК'), ('.', '.')]
# [('Спільні', 'ЛОК'), ('пральні', 'ЛОК'), ('й', 'ЛОК'), ('т.', 'ЛОК'), ('д.', 'ЛОК'), ('й', 'ЛОК'), ('т.', 'ЛОК'), ('п', 'ЛОК'), ('.', '.')]
# [('див', 'ПЕРС'), ('.', '.'), ('стор', 'VB'), ('.', '.'), ('24', 'CD'), ('.', '.')]
# [('Є.Бакуліна', 'ЛОК')]
# [('Від', 'ПЕРС'), ('англ.\\n', 'ОРГ'), ('File', 'ЛОК'), ('.', '.')]
# [('Від', 'ПЕРС'), ('фр', 'ЛОК'), ('.', '.'), ('\\nparachute', 'ЛОК'), ('.', '.')]
# [('В', 'ПЕРС'), ('цих', 'ЛОК'), ('світлих', 'ЛОК'), ('просторих', 'ЛОК'), ('апартаментах', 'ЛОК'), ('...', ':'), ('м', 'ЛОК'), ('’', 'ПЕРС'), ('які', 'ПЕРС'), ('крісла', 'РІЗН'), (',', ','), ('килими', 'UH'), (',', ','), ('дорогі', 'ЛОК'), ('статуетки', 'ЛОК')]
# [('(', '('), ('вони', 'ЛОК'), ('самі', 'ПЕРС'), ('це', 'ЛОК'), ('визнали', 'ЛОК'), ('.', '.'), ('-', ':'), ('Ред', 'NN'), ('.', '.'), (')', ')')]
# [('Всього', 'ПЕРС'), ('33', 'CD'), ('тис', 'NN'), ('.', '.'), ('356', 'CD'), ('особи', 'ЛОК')]
# [('Всього', 'ПЕРС'), ('33', 'CD'), ('тис', 'NN'), ('.', '.'), ('(', '('), ('за', 'ПЕРС'), ('словами', 'ОРГ'), ('прораба', 'ЛОК'), (')', ')')]
# [('з', 'ПЕРС'), ('яких', 'ЛОК'), ('приблизно', 'ЛОК'), ('1,2', 'CD'), ('тис', 'ЛОК'), ('.', '.'), ('–', 'ПЕРС'), ('чоловіки', 'ЛОК'), ('.', '.')]
# [('У', 'ЛОК'), ('с.', 'ОРГ'), ('Вижва', 'ЛОК')]
# [('Книжка', 'ЛОК'), ('(', '('), ('с', 'UH'), ('.', '.'), ('200', 'CD'), (')', ')')]
# [('позначені', 'ЛОК'), (':', ':'), ('«', 'ПЕРС'), ('с', 'ПЕРС'), ('.', '.'), ('Вижва', 'ПЕРС'), ('»', 'ЛОК')]
# [('Микола', 'ПЕРС'), ('Васюк', 'ЛОК'), ('(', '('), ('с.', 'ПЕРС'), ('Корнієнки', 'ЛОК'), (',', ','), ('Полтавська', 'ПЕРС'), ('обл', 'ОРГ'), ('.', '.'), (')', ')')]
# [('U.S.', 'NNP'), ('Marine', 'ЛОК')]
# [('B.B', 'ПЕРС'), ('.', '.'), ('King', 'VBG')]
# [('Церква', 'ПЕРС'), ('Св', 'ЛОК'), ('.', '.'), ('Духа', 'ПЕРС'), ('і', 'ЛОК'), ('церква', 'ЛОК'), ('св', 'ЛОК'), ('.', '.'), ('Духа', 'ЛОК')]
# [('Валерій', 'ПЕРС'), ('(', '('), ('міліціонер-пародист', 'ОРГ'), ('.', '.'), ('–', 'ОРГ'), ('Авт', 'ПЕРС'), ('.', '.'), (')', ')'), ('стане', 'VBD'), ('пародистом', 'ЛОК'), ('.', '.')]
# [('Сьогодні', 'ЛОК'), ('(', '('), ('у', 'ЛОК'), ('четвер', 'RB'), ('.', '.'), ('-', ':'), ('Ред', 'NN'), ('.', '.'), (')', ')'), (',', ','), ('вранці', 'UH'), ('.', '.')]
# [('(', '('), ('[', 'ОРГ'), ('27', 'CD'), (']', 'ОРГ'), ('див', 'ПЕРС'), ('.', '.'), ('Тиждень', 'ПЕРС'), ('№', '$'), ('9', 'CD'), (',', ','), ('2008', 'CD'), (')', ')')]
# [('Всього', 'ПЕРС'), ('33', 'CD'), ('тис', 'NNS'), ('.', '.')]
# [('А', 'ПЕРС'), ('можей', 'ОРГ'), ('й', 'ЛОК'), ('більше', 'ЛОК')]
# [('Їх', 'ПЕРС'), ('було', 'ЛОК'), ('7,5', 'CD'), ('млн', 'NNS'), ('.', '.')]
# [('В', 'ПЕРС'), ('кожного', 'ЛОК'), ('була', 'ПЕРС'), ('сорочка', 'ЛОК'), ('.', '.')]
# [('Довжиною', 'ПЕРС'), ('30', 'CD'), ('с', 'NNS'), ('.', '.')]
# [('Поїхали', 'ЛОК'), ('.', '.')]
# [('Швидкістю', 'ПЕРС'), ('30', 'CD'), ('м/с', 'NNS'), ('.', '.')]
# [('Поїхали', 'ЛОК'), ('.', '.')]
# [('Останні', 'ПЕРС'), ('100', 'CD'), ('м', 'NNS'), ('.', '.')]
# [('І', 'ПЕРС'), ('тут', 'ЛОК'), ('все', 'ЛОК'), ('пропало', 'ЛОК'), ('.', '.')]
# [('Корисна', 'ЛОК'), ('площа', 'ЛОК'), ('67', 'CD'), ('тис', 'ЛОК'), ('.', '.'), ('кв', 'ПЕРС'), ('.', '.'), ('м', 'ЛОК'), ('.', '.')]
# [('У', 'ЛОК'), ('1954', 'CD'), ('році', 'ЛОК'), ('над', 'ПЕРС'), ('Держпромом', 'ПЕРС'), ('...', ':')]
# [('На', 'ПЕРС'), ('0,6°C', 'CD'), ('.', '.')]
# [('Але', 'ПЕРС'), ('ми', 'ОРГ'), ('все', 'ЛОК'), ('маємо', 'ОРГ'), ('.', '.')]
# [('На', 'ПЕРС'), ('0,6°С', 'CD'), ('.', '.')]
# [('Але', 'ПЕРС'), ('ми', 'ОРГ'), ('все', 'ЛОК'), ('маємо', 'ОРГ'), ('.', '.')]
# [('На', 'ПЕРС'), ('0,6', 'CD'), ('°C', 'NNS'), ('.', '.')]
# [('Але', 'ПЕРС'), ('ми', 'ОРГ'), ('все', 'ЛОК'), ('маємо', 'ОРГ'), ('.', '.')]
# [('На', 'ПЕРС'), ('0,6', 'CD'), ('°С', 'NNS'), ('.', '.')]
# [('Але', 'ПЕРС'), ('ми', 'ОРГ'), ('все', 'ЛОК'), ('маємо', 'ОРГ'), ('.', '.')]
# [('Приїхав', 'ПЕРС'), ('у', 'ЛОК'), ('США', 'ЛОК'), ('.', '.')]
# [('Проте', 'ПЕРС'), ('на', 'ЛОК'), ('другий', 'ЛОК'), ('рік', 'ЛОК'), ('.', '.')]
# [('Маємо', 'ПЕРС'), ('страшне', 'ЛОК'), ('диво', 'ЛОК'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('.', '.')]
# [('І', 'ПЕРС'), ('кращого', 'ЛОК'), ('варіанту', 'ЛОК'), ('немає', 'ЛОК'), ('.', '.')]
# [('Вони', 'ПЕРС'), ('приїхали', 'ЛОК'), ('в', 'ЛОК'), ('Париж', 'ЛОК'), ('.', '.')]
# [('Але', 'ПЕРС'), ('там', 'ЛОК'), ('їм', 'ЛОК'), ('геть', 'ЛОК'), ('не', 'ЛОК'), ('сподобалося', 'ЛОК'), ('.', '.')]

# %%
for sent in small_sentences:
    if sent and not sent.isspace():
        words = nltk.tokenize.word_tokenize(sent)
        pos_tags_words = pos_tag(words)
        print(pos_tags_words)
# Out:
# [('http', 'NNS'), (':', ':'), ('//youtube.com:80/herewego', 'VB'), ('?', '.'), ('start=11', 'VB'), ('&', 'CC'), ('quality=high', 'VB'), ('%', 'NN'), ('3F', 'CD')]
# [('http', 'NNS'), (':', ':'), ('//youtube.com:80/herewego', 'VB'), ('?', '.'), ('start=11', 'VB'), ('&', 'CC'), ('quality=high', 'VB'), ('%', 'NN'), ('3F', 'CD')]
# [('300', 'CD'), ('грн', 'ЛОК'), ('на', 'ПЕРС'), ('балансі', 'ЛОК')]
# [('300', 'CD'), ('грн', 'ЛОК'), ('на', 'ПЕРС'), ('балансі', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('2,2', 'CD'), ('мільйона', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('2,2', 'CD'), ('мільйона', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('84,46', 'CD'), ('мільйона', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('84,46', 'CD'), ('мільйона', 'ЛОК')]
# [('в', 'ЛОК'), ('1996,1997,1998', 'CD')]
# [('в', 'ЛОК'), ('1996', 'CD'), (',', ','), ('1997', 'CD'), (',', ','), ('1998', 'CD')]
# [('надійшло', 'ПЕРС'), ('2', 'CD'), ('000', 'CD'), ('тон', 'ЛОК')]
# [('надійшло', 'ПЕРС'), ('2', 'CD'), ('000', 'CD'), ('тон', 'ЛОК')]
# [('сталося', 'ПЕРС'), ('14.07.2001', 'CD'), ('вночі', 'ЛОК')]
# [('сталося', 'ПЕРС'), ('14.07.2001', 'CD'), ('вночі', 'ЛОК')]
# [('вчора', 'ЛОК'), ('о', 'ОРГ'), ('7.30', 'CD'), ('ранку', 'ЛОК')]
# [('вчора', 'ЛОК'), ('о', 'ОРГ'), ('7.30', 'CD'), ('ранку', 'ЛОК')]
# [('Вони', 'ПЕРС'), ('прийшли', 'ЛОК'), ('додому', 'ЛОК'), ('.', '.')]
# [('Вони', 'ПЕРС'), ('прийшли', 'ЛОК'), ('додому', 'ЛОК'), ('.', '.')]
# [('Вони', 'ПЕРС'), ('прийшли', 'ЛОК'), ('пʼятими', 'ЛОК'), ('зів', 'ЛОК'), ('’', 'ЛОК'), ('ялими', 'ЛОК'), ('.', '.')]
# [('Вони', 'ПЕРС'), ('прийшли', 'ЛОК'), ('пʼятими', 'ЛОК'), ('зів', 'ЛОК'), ('’', 'ЛОК'), ('ялими', 'ЛОК'), ('.', '.')]
# [('я', 'ПЕРС'), ('українець', 'ЛОК'), ('(', '('), ('сміється', 'ЛОК')]
# [('я', 'ПЕРС'), ('українець', 'ЛОК'), ('(', '('), ('сміється', 'ЛОК')]
# [('ОУН', 'ПЕРС'), ('(', '('), ('б', 'ЛОК'), (')', ')'), ('та', 'ПЕРС'), ('КП', 'ЛОК'), ('(', '('), ('б', 'ЛОК'), (')', ')'), ('У', 'ЛОК')]
# [('ОУН', 'ПЕРС'), ('(', '('), ('б', 'ЛОК'), (')', ')'), ('та', 'ПЕРС'), ('КП', 'ЛОК'), ('(', '('), ('б', 'ЛОК'), (')', ')'), ('У', 'ЛОК')]
# [('Негода', 'ПЕРС'), ('є', 'ЛОК'), ('...', ':'), ('заступником', 'ЛОК')]
# [('Негода', 'ПЕРС'), ('є', 'ЛОК'), ('...', ':'), ('заступником', 'ЛОК')]
# [('Запагубили', 'ЛОК'), ('!', '.'), ('..', 'ЛОК'), ('також', 'ЛОК')]
# [('Запагубили', 'ЛОК'), ('!', '.'), ('..', 'ЛОК'), ('також', 'ЛОК')]
# [('Цей', 'ПЕРС'), ('графин', 'ЛОК'), ('.', '.')]
# [('Цей', 'ПЕРС'), ('графин', 'ЛОК'), ('.', '.')]
# [('—', 'ПЕРС'), ('Гм', 'ОРГ'), ('.', '.')]
# [('—', 'ПЕРС'), ('Гм', 'ОРГ'), ('.', '.')]
# [('Засідав', 'ЛОК'), ('І.Єрмолюк', 'ОРГ'), ('.', '.')]
# [('Засідав', 'ЛОК'), ('І', 'ОРГ'), ('.', '.'), ('Єрмолюк', 'ОРГ'), ('.', '.')]
# [('Засідав', 'ЛОК'), ('І.П.Єрмолюк', 'ОРГ'), ('.', '.')]
# [('Засідав', 'ЛОК'), ('І', 'ОРГ'), ('.', '.'), ('П', 'ОРГ'), ('.', '.'), ('Єрмолюк', 'ОРГ'), ('.', '.')]
# [('140', 'CD'), ('тис', 'ЛОК'), ('.', '.'), ('працівників', 'ЛОК')]
# [('140', 'CD'), ('тис', 'ЛОК'), ('.', '.'), ('працівників', 'ЛОК')]
# [('проф', 'ЛОК'), ('.', '.'), ('Артюхов', 'ЛОК')]
# [('проф', 'ЛОК'), ('.', '.'), ('Артюхов', 'ЛОК')]
# [('до', 'ПЕРС'), ('н.', 'ЛОК'), ('е', 'ЛОК'), ('.', '.')]
# [('до', 'ПЕРС'), ('н.', 'ЛОК'), ('е', 'ЛОК'), ('.', '.')]
# [('до', 'ПЕРС'), ('н.е', 'ЛОК'), ('.', '.')]
# [('до', 'ПЕРС'), ('н.', 'ЛОК'), ('е', 'ЛОК'), ('.', '.')]
# [('1998', 'CD'), ('р.н', 'ЛОК'), ('.', '.')]
# [('1998', 'CD'), ('р.', 'ОРГ'), ('н', 'ЛОК'), ('.', '.')]
# [('18-19', 'CD'), ('ст.ст', 'ОРГ'), ('.', '.'), ('були', 'ЛОК')]
# [('18-19', 'CD'), ('ст', 'ОРГ'), ('.', '.'), ('ст', 'ОРГ'), ('.', '.'), ('були', 'ЛОК')]
# [('І', 'ПЕРС'), ('ст', 'ЛОК'), ('.', '.'), ('11', 'CD')]
# [('І', 'ПЕРС'), ('ст', 'ЛОК'), ('.', '.'), ('11', 'CD')]
# [('У', 'ЛОК'), ('с.', 'ОРГ'), ('Вижва', 'ЛОК')]
# [('У', 'ЛОК'), ('с.', 'ОРГ'), ('Вижва', 'ЛОК')]
# [('Довжиною', 'ПЕРС'), ('30', 'CD'), ('с.', 'ЛОК'), ('з', 'ПЕРС'), ('гаком', 'ЛОК'), ('.', '.')]
# [('Довжиною', 'ПЕРС'), ('30', 'CD'), ('с', 'NN'), ('.', '.'), ('з', 'CC'), ('гаком', 'ПЕРС'), ('.', '.')]
# [('100', 'CD'), ('м.', 'ОРГ'), ('дороги', 'NNS'), ('.', '.')]
# [('100', 'CD'), ('м', 'ОРГ'), ('.', '.'), ('дороги', 'ОРГ'), ('.', '.')]
# [('На', 'ПЕРС'), ('висоті', 'ЛОК'), ('4000', 'CD'), ('м', 'ЛОК'), ('...', ':')]
# [('На', 'ПЕРС'), ('висоті', 'ЛОК'), ('4000', 'CD'), ('м', 'ЛОК'), ('...', ':')]
# [('№47', 'ПЕРС'), ('(', '('), ('м.', 'ЛОК'), ("Слов'янськ", 'ЛОК'), (')', ')')]
# [('№47', 'ПЕРС'), ('(', '('), ('м.', 'ЛОК'), ("Слов'янськ", 'ЛОК'), (')', ')')]
# [('с.-г', 'ЛОК'), ('.', '.')]
# [('с.-г', 'ЛОК'), ('.', '.')]
# [('100', 'CD'), ('грн', 'ЛОК'), ('.', '.'), ('в', 'ЛОК'), ('банк', 'ЛОК')]
# [('100', 'CD'), ('грн', 'ЛОК'), ('.', '.'), ('в', 'ЛОК'), ('банк', 'ЛОК')]
# [('таке', 'ПЕРС'), ('та', 'ЛОК'), ('ін', 'ЛОК'), ('.', '.')]
# [('таке', 'ПЕРС'), ('та', 'ЛОК'), ('ін', 'ЛОК'), ('.', '.')]
# [('і', 'ПЕРС'), ('т.', 'ЛОК'), ('ін', 'ЛОК'), ('.', '.')]
# [('і', 'ПЕРС'), ('т.', 'ЛОК'), ('ін', 'ЛОК'), ('.', '.')]
# [('Інститут', 'ПЕРС'), ('ім', 'ЛОК'), ('.', '.'), ('акад', 'ЛОК'), ('.', '.'), ('Вернадського', 'ПЕРС'), ('.', '.')]
# [('Інститут', 'ПЕРС'), ('ім', 'ЛОК'), ('.', '.'), ('акад', 'ЛОК'), ('.', '.'), ('Вернадського', 'ПЕРС'), ('.', '.')]
# [('Палац', 'ПЕРС'), ('ім', 'ЛОК'), ('.', '.'), ('гетьмана', 'ПЕРС'), ('Скоропадського', 'ЛОК'), ('.', '.')]
# [('Палац', 'ПЕРС'), ('ім', 'ЛОК'), ('.', '.'), ('гетьмана', 'ПЕРС'), ('Скоропадського', 'ЛОК'), ('.', '.')]
# [('від', 'ЛОК'), ('лат', 'ОРГ'), ('.', '.'), ('momento', 'VB')]
# [('від', 'ЛОК'), ('лат', 'ОРГ'), ('.', '.'), ('momento', 'VB')]
# [('на', 'ЛОК'), ('1-кімн', 'ОРГ'), ('.', '.'), ('кв', 'ОРГ'), ('.', '.'), ('в', 'ЛОК'), ('центрі', 'ЛОК')]
# [('на', 'ЛОК'), ('1-кімн', 'ОРГ'), ('.', '.'), ('кв', 'ОРГ'), ('.', '.'), ('в', 'ЛОК'), ('центрі', 'ЛОК')]
# [('Валерій', 'ПЕРС'), ('(', '('), ('міліціонер-пародист.–', 'ОРГ'), ('Авт', 'ПЕРС'), ('.', '.'), (')', ')'), ('стане', 'VBD'), ('пародистом', 'ЛОК'), ('.', '.')]
# [('Валерій', 'ПЕРС'), ('(', '('), ('міліціонер-пародист', 'ОРГ'), ('.', '.'), ('–', 'ОРГ'), ('Авт', 'ПЕРС'), ('.', '.'), (')', ')'), ('стане', 'VBD'), ('пародистом', 'ЛОК'), ('.', '.')]
# [('Сьогодні', 'ЛОК'), ('(', '('), ('у', 'ЛОК'), ('четвер', 'RB'), ('.', '.'), ('—', 'VB'), ('Ред', 'ЛОК'), ('.', '.'), (')', ')'), (',', ','), ('вранці', 'UH'), ('.', '.')]
# [('Сьогодні', 'ЛОК'), ('(', '('), ('у', 'ЛОК'), ('четвер', 'RB'), ('.', '.'), ('—', 'VB'), ('Ред', 'ЛОК'), ('.', '.'), (')', ')'), (',', ','), ('вранці', 'UH'), ('.', '.')]
# [('Fair', 'ПЕРС'), ('trade', 'NN'), ('[', 'ПЕРС'), ('«', 'ПЕРС'), ('Справедлива', 'ЛОК'), ('торгівля', 'ЛОК'), ('»', 'ЛОК'), ('.', '.'), ('–', 'ПЕРС'), ('Авт', 'ПЕРС'), ('.', '.'), (']', 'VB'), (',', ','), ('який', 'VB'), ('стежить', 'ПЕРС'), ('за', 'ОРГ'), ('тим', 'ЛОК'), (',', ','), ('щоб', 'ПЕРС'), ('у', 'ЛОК'), ('країнах', 'ЛОК')]
# [('Fair', 'ПЕРС'), ('trade', 'NN'), ('[', 'ПЕРС'), ('«', 'ПЕРС'), ('Справедлива', 'ЛОК'), ('торгівля', 'ЛОК'), ('»', 'ЛОК'), ('.', '.'), ('–', 'ПЕРС'), ('Авт', 'ПЕРС'), ('.', '.'), (']', 'VB'), (',', ','), ('який', 'VB'), ('стежить', 'ПЕРС'), ('за', 'ОРГ'), ('тим', 'ЛОК'), (',', ','), ('щоб', 'ПЕРС'), ('у', 'ЛОК'), ('країнах', 'ЛОК')]
# [('диво', 'ПЕРС'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('.', '.')]
# [('диво', 'ПЕРС'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('.', '.')]
# [('диво', 'ПЕРС'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('...', ':')]
# [('диво', 'ПЕРС'), ('з', 'ЛОК'), ('див', 'ЛОК'), ('...', ':')]
